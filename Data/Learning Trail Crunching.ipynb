# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data_path = "/Users/nus/aurek-data-crunch/data/"

# %%
lt = pd.read_csv(data_path+"learningTrail_sensing.csv")

# %%
lt
# Out:
#                                  key_0  light  noise  thermal  \
# 0     2019-01-20 14:00:06.481000+08:00   10.0   10.0     10.0
# 1     2019-01-21 11:27:24.594000+08:00   10.0   10.0     10.0
# 2     2019-01-21 11:27:48.407000+08:00   10.0   10.0     10.0
# 3     2019-01-21 11:50:16.461000+08:00   10.0   10.0     10.0
# 4     2019-01-22 11:46:36.601000+08:00   10.0   10.0     10.0
# 5     2019-01-25 21:07:15.256000+08:00   11.0    9.0     11.0
# 6     2019-01-26 19:40:38.397000+08:00   10.0   10.0     10.0
# 7     2019-01-27 16:03:23.145000+08:00   11.0   11.0     10.0
# 8     2019-01-27 22:12:34.404000+08:00   11.0   10.0     11.0
# 9     2019-01-28 17:35:26.161000+08:00   11.0   11.0     11.0
# 10    2019-01-28 17:43:22.629000+08:00   10.0   11.0     11.0
# 11    2019-01-28 17:46:50.425000+08:00   10.0   11.0     10.0
# 12    2019-01-29 15:47:46.638000+08:00   10.0   11.0     11.0
# 13    2019-01-29 15:50:30.311000+08:00   10.0   11.0     11.0
# ...

# %%
lt.light.value_counts()
# Out:
# 10.0    931
# 9.0     113
# 11.0     82
# Name: light, dtype: int64

# %%
lt.noise.value_counts()
# Out:
# 10.0    676
# 11.0    427
# 9.0      28
# Name: noise, dtype: int64

# %%
sm.thermal.value_counts()
# Out:
# 10.0    599
# 11.0    525
# 9.0      33
# Name: thermal, dtype: int64

# %%
lt.location.value_counts()
# Out:
# WELLNESS_TRAIL->WELLNESS_TRAIL                              144
# WATER_TRAIL->WATER_TRAIL                                    126
# TROPICAL_ARCHITECTURE_TRAIL->TROPICAL_ARCHITECTURE_TRAIL     90
# HYBRID_COOLING_TRAIL->HYBRID_COOLING_TRAIL                   90
# WELLNESS_TRAIL->AIR                                          66
# WELLNESS_TRAIL->LIGHTING                                     62
# WELLNESS_TRAIL->NUS_POLICY                                   62
# WATER_TRAIL->WATER_FEATURE                                   47
# NET_ZERO_ENERGY_TRAIL->ENERGY_GENERATION                     38
# WELLNESS_TRAIL->FUTURE_TECHNOLOGIES_1                        36
# TROPICAL_ARCHITECTURE_TRAIL->BUILDING_FORM                   31
# BIOPHILIC_DESIGN_TRAIL->NATURE_OF_PLACE                      28
# WELLNESS_TRAIL->FUTURE_TECHNOLOGIES_3                        27
# BIOPHILIC_DESIGN_TRAIL->BIOPHILIC_DESIGN_TRAIL               27
# TROPICAL_ARCHITECTURE_TRAIL->FUTURE_TECHNOLOGIES_1           27
# ...

# %%
lt.user_id.value_counts()
# Out:
# anon_q0t1to1bj56o     13
# anon_2cwdm8k1j1a0w    11
# anon_3or6x3z4lvc00    10
# anon_2ipxa8nse1xxc    10
# anon_2rs06bh3l4lq8    10
# anon_191vfn28tq9kw    10
# anon_2v3f3nhb5u3uo     9
# anon_y642jpi2q0ow      9
# anon_325ppkyu4w000     9
# anon_2u06qv6ynwq00     9
# anon_23x8h09xzdb40     9
# anon_2co84nsxjn6s0     9
# anon_4fqk92rtzbw0      8
# anon_1of5p32afw4xs     8
# anon_dpox2mw911q8      8
# anon_1jfgivai8h4ao     8
# anon_18czxmf2ed4w0     8
# anon_2obosdhd0s000     8
# anon_t0ezyafkh14w      8
# anon_2mxcm17ue4g00     8
# anon_29p1mj79qz1fk     8
# anon_3us7mly7p8200     8
# anon_1oaxrgioj9y4g     8
# anon_39m7ylo7dzs00     8
# anon_7wwrchb0r280      8
# anon_11dd7v99fug3k     8
# anon_2nf3oucbdcohs     8
# anon_1yqwirqqggi68     7
# anon_4iaif5l95720      7
# anon_217b9kkjb7280     7
#                       ..
# anon_209e8vf8xh2io     1
# anon_153z43aqkxvg0     1
# anon_3ki1p277n17nk     1
# anon_gwcfagyp88w0      1
# anon_3bmh30rwqoyrk     1
# anon_220ss5ghvg800     1
# ...

# %%
lt.location.count()
# Out:
# 1162

# %%
lt[lt.indoor==0].location.value_counts()
# Out:
# WELLNESS_TRAIL->WELLNESS_TRAIL                              144
# WATER_TRAIL->WATER_TRAIL                                    126
# TROPICAL_ARCHITECTURE_TRAIL->TROPICAL_ARCHITECTURE_TRAIL     90
# HYBRID_COOLING_TRAIL->HYBRID_COOLING_TRAIL                   90
# WELLNESS_TRAIL->NUS_POLICY                                   62
# WATER_TRAIL->WATER_FEATURE                                   47
# NET_ZERO_ENERGY_TRAIL->ENERGY_GENERATION                     38
# WELLNESS_TRAIL->FUTURE_TECHNOLOGIES_1                        36
# TROPICAL_ARCHITECTURE_TRAIL->BUILDING_FORM                   31
# BIOPHILIC_DESIGN_TRAIL->NATURE_OF_PLACE                      28
# TROPICAL_ARCHITECTURE_TRAIL->FUTURE_TECHNOLOGIES_1           27
# WELLNESS_TRAIL->FUTURE_TECHNOLOGIES_3                        27
# BIOPHILIC_DESIGN_TRAIL->BIOPHILIC_DESIGN_TRAIL               27
# WATER_TRAIL->BIO_RETENTION_BASIN                             25
# WELLNESS_TRAIL->MOVEMENT                                     25
# ...

# %%
lt[lt.indoor==0].location.count()
# Out:
# 925

# %%
lt[lt.indoor==1].location.count()
# Out:
# 237

# %%
measurement_type = {'light':{9:"prefer dimmer", 10:"comfy", 11:"prefer brighter"}, "thermal":{9: "prefer warmer", 10:"comfy", 11:"prefer cooler"}, "noise":{9: "prefer louder", 10:"comfy", 11:"prefer quiter"}}

# %%
for measurement in measurement_type:
    print(measurement)
    df = pd.pivot_table(data=lt, index=sm.index, columns="user_id", values=measurement)
    df = df[lt.user_id.value_counts().head(20).index]
    #df = df.replace(measurement_type[measurement])
    ax = df.hist(figsize=(20,20))

    plt.show()
# Out:
# light
# thermal
# noise

# %%
plt.matshow(lt.corr())

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(lt.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(lt.corr(), mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(lt[lt.indoor==0].corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(lt[lt.indoor==0].corr(), mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(lt[lt.indoor==1].corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(lt[lt.indoor==1].corr(), mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.set(font_scale=1.5)

lt.hist(figsize=(20,20), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a39519390>,
# ...
#       dtype=object)

# %%
lt[lt.indoor==1].hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a410ecf98>,
# ...
#       dtype=object)

# %%
lt[lt.indoor==0].hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a42f64c50>,
# ...
#       dtype=object)

# %%
lt[lt.indoor==0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 925 entries, 0 to 1108
# Data columns (total 15 columns):
# key_0          925 non-null object
# light          892 non-null float64
# noise          896 non-null float64
# thermal        921 non-null float64
# location       925 non-null object
# user_id        925 non-null object
# room           925 non-null object
# indoor         925 non-null int64
# co2            825 non-null float64
# humidity       825 non-null float64
# lightLevel     825 non-null float64
# noiseLevel     825 non-null float64
# presence       825 non-null float64
# temperature    825 non-null float64
# voc            825 non-null float64
# dtypes: float64(10), int64(1), object(4)
# memory usage: 115.6+ KB

# %%
lt = pd.read_csv(data_path+"learningTrail_sensing.csv")

# %%
lt.light = lt.light.replace({9:"prefer dimmer", 10:"comfy", 11:"prefer brighter"})
sns.pairplot(lt[lt.indoor==0][["lightLevel","presence","light","temperature","co2"]].dropna(), hue="light")
g.fig.suptitle("OUTDOOR LIGHT")
# Out:
# Text(0.5,0.98,'OUTDOOR LIGHT')

# %%
lt[lt.indoor==0].light.value_counts()
# Out:
# comfy              736
# prefer brighter     80
# prefer dimmer       76
# Name: light, dtype: int64

# %%
sns.pairplot(lt[lt.indoor==1][["lightLevel","presence","light","temperature","co2"]].dropna(), hue="light")
g.fig.suptitle("INDOOR LIGHT")
# Out:
# Text(0.5,0.98,'INDOOR LIGHT')

# %%
lt[lt.indoor==1].light.value_counts()
# Out:
# comfy              195
# prefer dimmer       37
# prefer brighter      2
# Name: light, dtype: int64

# %%
lt.head()
# Out:
#                               key_0  light  noise  thermal  \
# 0  2019-01-20 14:00:06.481000+08:00  comfy   10.0     10.0
# 1  2019-01-21 11:27:24.594000+08:00  comfy   10.0     10.0
# 2  2019-01-21 11:27:48.407000+08:00  comfy   10.0     10.0
# 3  2019-01-21 11:50:16.461000+08:00  comfy   10.0     10.0
# 4  2019-01-22 11:46:36.601000+08:00  comfy   10.0     10.0
#
#                                   location             user_id  \
# 0  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
# 1  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
# 2  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
# 3  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
# 4  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
#
#                    room  indoor     co2  humidity  lightLevel  noiseLevel  \
# 0  PLANTER_BOX_NEAR_LAB       0  1258.0   52.4773       266.0        47.0
# 1  PLANTER_BOX_NEAR_LAB       0  1258.0   52.4773       266.0        47.0
# ...

# %%
lt[lt.indoor==1][["noiseLevel","presence","noise","co2"]].dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 242 to 1161
# Data columns (total 4 columns):
# noiseLevel    221 non-null float64
# presence      221 non-null float64
# noise         221 non-null float64
# co2           221 non-null float64
# dtypes: float64(4)
# memory usage: 8.6 KB

# %%
lt[lt.indoor==1][["noiseLevel","presence","noise","co2"]].dropna().head()
# Out:
#      noiseLevel  presence  noise     co2
# 242        46.0       3.0   11.0  1118.0
# 243        46.0       3.0   10.0  1118.0
# 244        46.0       3.0   10.0  1118.0
# 245        46.0       3.0   11.0  1118.0
# 246        46.0       3.0   10.0  1118.0

# %%
lt.noise = lt.noise.replace({9: "prefer louder", 10:"comfy", 11:"prefer quieter"})
g = sns.pairplot(lt[lt.indoor==0][["noiseLevel","presence","noise","co2","temperature"]].dropna(), hue="noise")
g.fig.suptitle("OUTDOOR NOISE")
# Out:
# Text(0.5,0.98,'OUTDOOR NOISE')

# %%
g = sns.pairplot(lt[lt.indoor==1][["noiseLevel","presence","temperature","co2"]].dropna())
g.fig.suptitle("INDOOR NOISE")
# Out:
# Text(0.5,0.98,'INDOOR NOISE')

# %%
lt[lt.indoor==0].noise.value_counts()
# Out:
# comfy             465
# prefer quieter    406
# prefer louder      25
# Name: noise, dtype: int64

# %%
lt[lt.indoor==1].noise.value_counts()
# Out:
# comfy             211
# prefer quieter     21
# prefer louder       3
# Name: noise, dtype: int64

# %%
lt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1162 entries, 0 to 1161
# Data columns (total 15 columns):
# key_0          1162 non-null object
# light          1126 non-null object
# noise          1131 non-null object
# thermal        1157 non-null float64
# location       1162 non-null object
# user_id        1162 non-null object
# room           1162 non-null object
# indoor         1162 non-null int64
# co2            1048 non-null float64
# humidity       1048 non-null float64
# lightLevel     1048 non-null float64
# noiseLevel     1048 non-null float64
# presence       1048 non-null float64
# temperature    1048 non-null float64
# voc            1048 non-null float64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 136.2+ KB

# %%
lt.thermal = lt.thermal.replace({9: "prefer warmer", 10:"comfy", 11:"prefer cooler"})
g = sns.pairplot(lt[lt.indoor==1][["lightLevel","thermal","temperature","humidity"]].dropna(), hue="thermal")
g.fig.suptitle("INDOOR THERMAL")
# Out:
# Text(0.5,0.98,'INDOOR THERMAL')

# %%
g = sns.pairplot(lt[lt.indoor==0][["lightLevel","thermal","temperature","humidity"]].dropna(), hue="thermal")
g.fig.suptitle("LEARNING TRAIL OUTDOOR THERMAL")
# Out:
# Text(0.5,0.98,'LEARNING TRAIL OUTDOOR THERMAL')

# %%
lt[lt.indoor==1].thermal.value_counts()
# Out:
# comfy            168
# prefer cooler     61
# prefer warmer      7
# Name: thermal, dtype: int64

# %%
lt[lt.indoor==0].thermal.value_counts()
# Out:
# prefer cooler    464
# comfy            431
# prefer warmer     26
# Name: thermal, dtype: int64

# %%
lt.location.value_counts()
# Out:
# WELLNESS_TRAIL->WELLNESS_TRAIL                              144
# WATER_TRAIL->WATER_TRAIL                                    126
# TROPICAL_ARCHITECTURE_TRAIL->TROPICAL_ARCHITECTURE_TRAIL     90
# HYBRID_COOLING_TRAIL->HYBRID_COOLING_TRAIL                   90
# WELLNESS_TRAIL->AIR                                          66
# WELLNESS_TRAIL->LIGHTING                                     62
# WELLNESS_TRAIL->NUS_POLICY                                   62
# WATER_TRAIL->WATER_FEATURE                                   47
# NET_ZERO_ENERGY_TRAIL->ENERGY_GENERATION                     38
# WELLNESS_TRAIL->FUTURE_TECHNOLOGIES_1                        36
# TROPICAL_ARCHITECTURE_TRAIL->BUILDING_FORM                   31
# BIOPHILIC_DESIGN_TRAIL->NATURE_OF_PLACE                      28
# WELLNESS_TRAIL->FUTURE_TECHNOLOGIES_3                        27
# BIOPHILIC_DESIGN_TRAIL->BIOPHILIC_DESIGN_TRAIL               27
# TROPICAL_ARCHITECTURE_TRAIL->FUTURE_TECHNOLOGIES_1           27
# ...

# %%
g = sns.pairplot(lt[lt.location=="WELLNESS_TRAIL->WELLNESS_TRAIL"][["lightLevel","thermal","temperature","humidity"]].dropna(), hue="thermal")
g.fig.suptitle("WELLNESS_TRAIL->WELLNESS_TRAIL")
# Out:
# Text(0.5,0.98,'WELLNESS_TRAIL->WELLNESS_TRAIL')

# %%
lt[lt.location=="WELLNESS_TRAIL->WELLNESS_TRAIL"].thermal.value_counts()
# Out:
# comfy            84
# prefer cooler    57
# prefer warmer     3
# Name: thermal, dtype: int64

# %%
g = sns.pairplot(lt[lt.location=="WATER_TRAIL->WATER_TRAIL"][["lightLevel","thermal","temperature","humidity"]].dropna(), hue="thermal")
g.fig.suptitle("WATER_TRAIL->WATER_TRAIL")
# Out:
# Text(0.5,0.98,'WATER_TRAIL->WATER_TRAIL')

# %%
lt.user_id.value_counts().plot(kind='bar')

# %%
lt.head()
# Out:
#                               key_0  light  noise thermal  \
# 0  2019-01-20 14:00:06.481000+08:00  comfy  comfy   comfy
# 1  2019-01-21 11:27:24.594000+08:00  comfy  comfy   comfy
# 2  2019-01-21 11:27:48.407000+08:00  comfy  comfy   comfy
# 3  2019-01-21 11:50:16.461000+08:00  comfy  comfy   comfy
# 4  2019-01-22 11:46:36.601000+08:00  comfy  comfy   comfy
#
#                                   location             user_id  \
# 0  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
# 1  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
# 2  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
# 3  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
# 4  BIOPHILIC_DESIGN_TRAIL->NATURE_IN_PLACE  anon_23x8h09xzdb40
#
#                    room  indoor     co2  humidity  lightLevel  noiseLevel  \
# 0  PLANTER_BOX_NEAR_LAB       0  1258.0   52.4773       266.0        47.0
# 1  PLANTER_BOX_NEAR_LAB       0  1258.0   52.4773       266.0        47.0
# ...

# %%
lt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1162 entries, 0 to 1161
# Data columns (total 15 columns):
# key_0          1162 non-null object
# light          1126 non-null object
# noise          1131 non-null object
# thermal        1157 non-null object
# location       1162 non-null object
# user_id        1162 non-null object
# room           1162 non-null object
# indoor         1162 non-null int64
# co2            1048 non-null float64
# humidity       1048 non-null float64
# lightLevel     1048 non-null float64
# noiseLevel     1048 non-null float64
# presence       1048 non-null float64
# temperature    1048 non-null float64
# voc            1048 non-null float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 136.2+ KB

# %%
lt.room.value_counts()
# Out:
# IRC_LIBRARY                                425
# TERRACE                                    149
# CORRIDOR                                   132
# PLANTER_BOX_NEAR_LAB                        93
# OPEN_EXHIBITION_SPACE_2                     88
# IRC_LIBRARY_2                               66
# OPEN_EXHIBITION_SPACE_1                     62
# HOT_DESKING_ARCHITECTURE_STUDIO_SPACE_5     38
# ENERGY_LAB_1                                26
# HOT_DESKING_ARCHITECTURE_STUDIO_SPACE_2     21
# HOT_DESKING_ARCHITECTURE_STUDIO_SPACE_4     17
# NEAR_DIC_STUDIO_1                           15
# HOT_DESKING_ARCHITECTURE_STUDIO_SPACE_3     10
# NEAR_DIC_STUDIO_2                            8
# OUTSIDE_3D_SCANNING_LAB                      7
# DESIGN_STUDIO                                5
# Name: room, dtype: int64

# %%
g = sns.catplot(x="thermal", y="temperature", col="indoor",
                capsize=.2, palette="YlGnBu_d", height=6, aspect=.75,
                kind="point", data=lt)

# %%
g = sns.catplot(x="thermal", y="humidity", col="indoor",
                capsize=.2, palette="YlGnBu_d", height=6, aspect=.75,
                kind="point", data=lt)

# %%
lt
# Out:
#                                  key_0            light           noise  \
# 0     2019-01-20 14:00:06.481000+08:00            comfy           comfy
# 1     2019-01-21 11:27:24.594000+08:00            comfy           comfy
# 2     2019-01-21 11:27:48.407000+08:00            comfy           comfy
# 3     2019-01-21 11:50:16.461000+08:00            comfy           comfy
# 4     2019-01-22 11:46:36.601000+08:00            comfy           comfy
# 5     2019-01-25 21:07:15.256000+08:00  prefer brighter   prefer louder
# 6     2019-01-26 19:40:38.397000+08:00            comfy           comfy
# 7     2019-01-27 16:03:23.145000+08:00  prefer brighter  prefer quieter
# 8     2019-01-27 22:12:34.404000+08:00  prefer brighter           comfy
# 9     2019-01-28 17:35:26.161000+08:00  prefer brighter  prefer quieter
# 10    2019-01-28 17:43:22.629000+08:00            comfy  prefer quieter
# 11    2019-01-28 17:46:50.425000+08:00            comfy  prefer quieter
# ...

# %%
top20users = set(list(lt.user_id.value_counts().head(20).index))

# %%
lt_filter = lt[lt.user_id.isin(top20users)]

# %%
lt_filter.thermal.value_counts()
# Out:
# comfy            95
# prefer cooler    85
# prefer warmer     2
# Name: thermal, dtype: int64

# %%
g = sns.FacetGrid(lt_filter, col="user_id", hue='thermal', col_wrap=4, height=3.8, hue_order=["prefer cooler", "comfy", "prefer warmer"],)
g = (g.map(plt.scatter, "temperature", "humidity", s=150).add_legend())

# %%
lt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1162 entries, 0 to 1161
# Data columns (total 15 columns):
# key_0          1162 non-null object
# light          1126 non-null object
# noise          1131 non-null object
# thermal        1157 non-null object
# location       1162 non-null object
# user_id        1162 non-null object
# room           1162 non-null object
# indoor         1162 non-null int64
# co2            1048 non-null float64
# humidity       1048 non-null float64
# lightLevel     1048 non-null float64
# noiseLevel     1048 non-null float64
# presence       1048 non-null float64
# temperature    1048 non-null float64
# voc            1048 non-null float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 136.2+ KB

# %%
lt.location.value_counts().head(20)
# Out:
# WELLNESS_TRAIL->WELLNESS_TRAIL                              144
# WATER_TRAIL->WATER_TRAIL                                    126
# TROPICAL_ARCHITECTURE_TRAIL->TROPICAL_ARCHITECTURE_TRAIL     90
# HYBRID_COOLING_TRAIL->HYBRID_COOLING_TRAIL                   90
# WELLNESS_TRAIL->AIR                                          66
# WELLNESS_TRAIL->LIGHTING                                     62
# WELLNESS_TRAIL->NUS_POLICY                                   62
# WATER_TRAIL->WATER_FEATURE                                   47
# NET_ZERO_ENERGY_TRAIL->ENERGY_GENERATION                     38
# WELLNESS_TRAIL->FUTURE_TECHNOLOGIES_1                        36
# TROPICAL_ARCHITECTURE_TRAIL->BUILDING_FORM                   31
# BIOPHILIC_DESIGN_TRAIL->NATURE_OF_PLACE                      28
# WELLNESS_TRAIL->FUTURE_TECHNOLOGIES_3                        27
# BIOPHILIC_DESIGN_TRAIL->BIOPHILIC_DESIGN_TRAIL               27
# TROPICAL_ARCHITECTURE_TRAIL->FUTURE_TECHNOLOGIES_1           27
# ...

# %%
top20location = set(list(lt.location.value_counts().head(20).index))
lt_filter_location = lt[lt.location.isin(top20location)]

# %%
lt_filter_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1019 entries, 7 to 1139
# Data columns (total 15 columns):
# key_0          1019 non-null object
# light          986 non-null object
# noise          990 non-null object
# thermal        1015 non-null object
# location       1019 non-null object
# user_id        1019 non-null object
# room           1019 non-null object
# indoor         1019 non-null int64
# co2            920 non-null float64
# humidity       920 non-null float64
# lightLevel     920 non-null float64
# noiseLevel     920 non-null float64
# presence       920 non-null float64
# temperature    920 non-null float64
# voc            920 non-null float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 127.4+ KB

# %%
g = sns.FacetGrid(lt_filter_location, col="location", hue='thermal', col_wrap=4, height=7)
g = (g.map(plt.scatter, "temperature", "humidity", s=150).add_legend())

# %%
lt_filter_location[lt_filter_location.location == "BIOPHILIC_DESIGN_TRAIL->NATURE_OF_PLACE"]
# Out:
#                                key_0            light           noise  \
# 12  2019-01-29 15:47:46.638000+08:00            comfy  prefer quieter
# 15  2019-01-30 12:05:46.033000+08:00            comfy  prefer quieter
# 18  2019-02-11 12:08:26.681000+08:00            comfy           comfy
# 19  2019-02-11 15:07:20.264000+08:00            comfy  prefer quieter
# 20  2019-02-11 15:07:42.714000+08:00    prefer dimmer           comfy
# 21  2019-02-11 15:07:44.224000+08:00            comfy  prefer quieter
# 22  2019-02-11 15:07:45.635000+08:00            comfy  prefer quieter
# 23  2019-02-11 15:07:46.111000+08:00            comfy  prefer quieter
# 25  2019-02-11 15:08:06.400000+08:00            comfy           comfy
# 27  2019-02-13 11:16:16.552000+08:00            comfy  prefer quieter
# 28  2019-02-13 11:16:18.027000+08:00  prefer brighter  prefer quieter
# 29  2019-02-13 11:16:19.049000+08:00  prefer brighter  prefer quieter
# ...
